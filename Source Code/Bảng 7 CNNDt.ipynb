# %%
import numpy as np
import pandas as pd
import datetime
import copy
from keras.models import Sequential
from keras.layers import LSTM, Dense
import tensorflow as tf
from tensorflow import keras
from keras.layers import TimeDistributed, Conv1D, MaxPool1D, Flatten, LSTM, Dense, AveragePooling1D, Dropout, Conv2D, MaxPool2D
from keras.models import Sequential
from keras.regularizers import l2
import sklearn.metrics as metrics
from pyarrow import feather

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def data_processing(df, NUM_FEATURES):
   y_train = df['Label']
   flow_id = df['flow_id']

   df = df/255

   X_train = df.drop(['Label', 'flow_id'], axis=1)
   X_train = X_train.to_numpy()

   X_train = X_train.reshape(-1, 20, NUM_FEATURES, 1)
   y_train = y_train.to_numpy()

   y_train = y_train.reshape(-1,20)[:,-1]
   return X_train, y_train
def DoiNhan(label: np.array):
  for i in range(len(label)):
    if label[i] == 14 or label[i] == 16 or label[i] == 13:
      label[i] = 2
    elif label[i] == 11 or label[i] == 5 or label[i] == 10:
      label[i] = 1
    elif label[i] == 4 or label[i] == 8 or label[i] == 9 or label[i] == 1 or label[i] == 7:
      label[i] = 0

# %%
NUM_EPOCHS = 200
BATCH_SIZE = 32
client_lr = 3e-4

# %%
def train_CNN(X, y, X_test):
    model = Sequential()
    model.add(Conv2D(filters=128, kernel_size=(5, 5), padding='Same',
                     activation='relu', input_shape=(20,128,1)))
    model.add(Conv2D(filters=64 , kernel_size=(5, 5), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.1))
    model.add(Dense(3, activation="softmax"))

    model.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=client_lr), loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

    model.fit(X, y, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, shuffle=True)
    predictions = model.predict(X_test, verbose=2, batch_size=BATCH_SIZE)
    y_pred = np.argmax(predictions, axis=-1)

    return y_pred

# %%
def Training_Step():
  path = '/content/drive/MyDrive/Fixed_data/'
  test_name = 'd1test'
  train_name ='d1train'
  BATCH_SIZE = 32

  for i in range(9, 10):
    same_distribution = feather.read_feather(path + train_name + str(i))
    test_data = feather.read_feather(path + test_name + str(i))

    same, same_label = data_processing(same_distribution, 128)
    DoiNhan(same_label)

    X_train, y_train = same, same_label
    X_test, y_test = data_processing(test_data, 128)
    DoiNhan(y_test)

    y_pred = train_CNN(X_train, y_train, X_test)
    print(metrics.classification_report(y_test, y_pred))

# %%
model = Training_Step()
# Out:
# Epoch 1/200
# 26/26 [==============================] - 4s 70ms/step - loss: 1.0361 - sparse_categorical_accuracy: 0.5125
# Epoch 2/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.9218 - sparse_categorical_accuracy: 0.5162
# Epoch 3/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.7506 - sparse_categorical_accuracy: 0.6297
# Epoch 4/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.6256 - sparse_categorical_accuracy: 0.7045
# Epoch 5/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.4981 - sparse_categorical_accuracy: 0.7880
# Epoch 6/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.4772 - sparse_categorical_accuracy: 0.7905
# Epoch 7/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.4060 - sparse_categorical_accuracy: 0.8180
# Epoch 8/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.4275 - sparse_categorical_accuracy: 0.8217
# Epoch 9/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3526 - sparse_categorical_accuracy: 0.8479
# Epoch 10/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3209 - sparse_categorical_accuracy: 0.8678
# Epoch 11/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3005 - sparse_categorical_accuracy: 0.8778
# Epoch 12/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.4153 - sparse_categorical_accuracy: 0.8130
# Epoch 13/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3170 - sparse_categorical_accuracy: 0.8466
# Epoch 14/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3107 - sparse_categorical_accuracy: 0.8616
# Epoch 15/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3366 - sparse_categorical_accuracy: 0.8554
# Epoch 16/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.2973 - sparse_categorical_accuracy: 0.8641
# Epoch 17/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.8554
# Epoch 18/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.2799 - sparse_categorical_accuracy: 0.8853
# Epoch 19/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.2653 - sparse_categorical_accuracy: 0.8815
# Epoch 20/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.2438 - sparse_categorical_accuracy: 0.8953
# Epoch 21/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.2421 - sparse_categorical_accuracy: 0.9077
# Epoch 22/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2059 - sparse_categorical_accuracy: 0.9190
# Epoch 23/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2353 - sparse_categorical_accuracy: 0.9015
# Epoch 24/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2077 - sparse_categorical_accuracy: 0.9077
# Epoch 25/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9202
# Epoch 26/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.2001 - sparse_categorical_accuracy: 0.9252
# Epoch 27/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2560 - sparse_categorical_accuracy: 0.8990
# Epoch 28/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1751 - sparse_categorical_accuracy: 0.9289
# Epoch 29/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1846 - sparse_categorical_accuracy: 0.9227
# Epoch 30/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1610 - sparse_categorical_accuracy: 0.9426
# Epoch 31/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9302
# Epoch 32/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1388 - sparse_categorical_accuracy: 0.9526
# Epoch 33/200
# 26/26 [==============================] - 1s 24ms/step - loss: 0.1333 - sparse_categorical_accuracy: 0.9539
# Epoch 34/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.1127 - sparse_categorical_accuracy: 0.9651
# Epoch 35/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.1431 - sparse_categorical_accuracy: 0.9514
# Epoch 36/200
# 26/26 [==============================] - 1s 24ms/step - loss: 0.1201 - sparse_categorical_accuracy: 0.9514
# Epoch 37/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1025 - sparse_categorical_accuracy: 0.9663
# Epoch 38/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1211 - sparse_categorical_accuracy: 0.9589
# Epoch 39/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1001 - sparse_categorical_accuracy: 0.9589
# Epoch 40/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0713 - sparse_categorical_accuracy: 0.9738
# Epoch 41/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9751
# Epoch 42/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9688
# Epoch 43/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9688
# Epoch 44/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9825
# Epoch 45/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9850
# Epoch 46/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.1312 - sparse_categorical_accuracy: 0.9514
# Epoch 47/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0589 - sparse_categorical_accuracy: 0.9813
# Epoch 48/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9850
# Epoch 49/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9875
# Epoch 50/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9825
# Epoch 51/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0433 - sparse_categorical_accuracy: 0.9825
# Epoch 52/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0535 - sparse_categorical_accuracy: 0.9763
# Epoch 53/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1334 - sparse_categorical_accuracy: 0.9464
# Epoch 54/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9676
# Epoch 55/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9838
# Epoch 56/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9825
# Epoch 57/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9925
# Epoch 58/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9925
# Epoch 59/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0256 - sparse_categorical_accuracy: 0.9938
# Epoch 60/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9925
# Epoch 61/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1239 - sparse_categorical_accuracy: 0.9576
# Epoch 62/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0989 - sparse_categorical_accuracy: 0.9589
# Epoch 63/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0885 - sparse_categorical_accuracy: 0.9663
# Epoch 64/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0781 - sparse_categorical_accuracy: 0.9701
# Epoch 65/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9900
# Epoch 66/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9913
# Epoch 67/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9913
# Epoch 68/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9938
# Epoch 69/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9925
# Epoch 70/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9938
# Epoch 71/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9963
# Epoch 72/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9863
# Epoch 73/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9863
# Epoch 74/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.1705 - sparse_categorical_accuracy: 0.9426
# Epoch 75/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9738
# Epoch 76/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9788
# Epoch 77/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9850
# Epoch 78/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9938
# Epoch 79/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9950
# Epoch 80/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9963
# Epoch 81/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9975
# Epoch 82/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9950
# Epoch 83/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9938
# Epoch 84/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9938
# Epoch 85/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9950
# Epoch 86/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9963
# Epoch 87/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9950
# Epoch 88/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9988
# Epoch 89/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000
# Epoch 90/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9975
# Epoch 91/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9963
# Epoch 92/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9988
# Epoch 93/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000
# Epoch 94/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9975
# Epoch 95/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9963
# Epoch 96/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9950
# Epoch 97/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9963
# Epoch 98/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0109 - sparse_categorical_accuracy: 0.9950
# Epoch 99/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000
# Epoch 100/200
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9975
# Epoch 101/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9975
# Epoch 102/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9950
# Epoch 103/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9988
# Epoch 104/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9963
# Epoch 105/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0038 - sparse_categorical_accuracy: 1.0000
# Epoch 106/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9975
# Epoch 107/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9975
# Epoch 108/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9963
# Epoch 109/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9988
# Epoch 110/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000
# Epoch 111/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000
# Epoch 112/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9975
# Epoch 113/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9988
# Epoch 114/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000
# Epoch 115/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988
# Epoch 116/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9975
# Epoch 117/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9938
# Epoch 118/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9925
# Epoch 119/200
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0065 - sparse_categorical_accuracy: 1.0000
# Epoch 120/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9950
# Epoch 121/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9925
# Epoch 122/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000
# Epoch 123/200
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000
# Epoch 124/200
# 13/26 [==============>...............] - ETA: 0s - loss: 0.0015 - sparse_categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-af091eb63cc1> in <cell line: 1>()
# ----> 1 model = Training_Step()
#
# <ipython-input-11-bb72724e2f77> in Training_Step()
#      16     DoiNhan(y_test)
#      17
# ---> 18     y_pred = train_CNN(X_train, y_train, X_test)
#      19     print(metrics.classification_report(y_test, y_pred))
#      20
#
# <ipython-input-6-e4b4ad8e641d> in train_CNN(X, y, X_test)
#      31     metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
#      32
# ---> 33     model.fit(X, y, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, shuffle=True)
#      34     predictions = model.predict(X_test, verbose=2, batch_size=BATCH_SIZE)
#      35     y_pred = np.argmax(predictions, axis=-1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1811                             logs = tmp_logs
#    1812                             end_step = step + data_handler.step_increment
# -> 1813                             callbacks.on_train_batch_end(end_step, logs)
#    1814                             if self.stop_training:
#    1815                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     392     """
#     393     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     396
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     358   def _numpy(self):
#     359     try:
# --> 360       return self._numpy_internal()
#     361     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
