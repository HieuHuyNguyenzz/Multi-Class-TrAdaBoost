# %%
import numpy as np
import pandas as pd
import datetime
import copy
from keras.models import Sequential
from keras.layers import LSTM, Dense
import tensorflow as tf
from tensorflow import keras
from keras.layers import TimeDistributed, Conv1D, MaxPool1D, Flatten, LSTM, Dense, AveragePooling1D, Dropout, Conv2D, MaxPool2D
from keras.models import Sequential
from keras.regularizers import l2
import sklearn.metrics as metrics
from pyarrow import feather

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def data_processing(df, NUM_FEATURES):
   y_train = df['Label']
   flow_id = df['flow_id']

   df = df/255

   X_train = df.drop(['Label', 'flow_id'], axis=1)
   X_train = X_train.to_numpy()

   X_train = X_train.reshape(-1, 20, NUM_FEATURES, 1)
   y_train = y_train.to_numpy()

   y_train = y_train.reshape(-1,20)[:,-1]
   return X_train, y_train
def DoiNhan(label: np.array):
  for i in range(len(label)):
    if label[i] == 14 or label[i] == 16 or label[i] == 13:
      label[i] = 2
    elif label[i] == 11 or label[i] == 5 or label[i] == 10:
      label[i] = 1
    elif label[i] == 4 or label[i] == 8 or label[i] == 9 or label[i] == 1 or label[i] == 7:
      label[i] = 0

# %%
NUM_EPOCHS = 100
BATCH_SIZE = 32
client_lr = 3e-4

# %%
from keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def train_CNN(X, y, X_test, y_test):
    model = Sequential()
    model.add(Conv2D(filters=128, kernel_size=(5, 5), padding='Same',
                     activation='relu', input_shape=(20,128,1)))
    model.add(Conv2D(filters=64 , kernel_size=(5, 5), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(Conv2D(filters=8, kernel_size=(3, 3), padding='Same',
                     activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.1))
    model.add(Dense(3, activation="softmax"))

    model.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=client_lr), loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
    for i in range(5):
      model.fit(X, y, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, shuffle=True)
      predictions = model.predict(X_test, verbose=2, batch_size=BATCH_SIZE)
      y_pred = np.argmax(predictions, axis=-1)
      print(str((i + 1) * 100) + ' epochs result: ')
      print(metrics.classification_report(y_test, y_pred))

    return model

# %%
def Training_Step():
  path = '/content/drive/MyDrive/Fixed_data/'
  test_name = 'd1test'
  train_name ='d1train'
  BATCH_SIZE = 32

  res = []
  train_data = feather.read_feather(path + train_name + str(1))
  test_data = feather.read_feather(path + test_name + str(1))

  X_train, y_train = data_processing(train_data, 128)
  X_test, y_test = data_processing(test_data, 128)

  DoiNhan(y_train)
  DoiNhan(y_test)

  CNN_model = train_CNN(X_train, y_train, X_test, y_test)
  return CNN_model

# %%
model = Training_Step()
# Out:
# Epoch 1/100
# 3/3 [==============================] - 10s 2s/step - loss: 1.0970 - sparse_categorical_accuracy: 0.4205
# Epoch 2/100
# 3/3 [==============================] - 10s 4s/step - loss: 1.0913 - sparse_categorical_accuracy: 0.5114
# Epoch 3/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.0736 - sparse_categorical_accuracy: 0.5341
# Epoch 4/100
# 3/3 [==============================] - 9s 3s/step - loss: 1
100
# 3/3 [==============================] - 8s 2s/step - loss: 0.3408 - sparse_categorical_accuracy: 0.8750
# Epoch 84/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1560 - sparse_categorical_accuracy: 0.9545
# Epoch 85/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.1740 - sparse_categorical_accuracy: 0.9773
# Epoch 86/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9432
# Epoch 87/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.1699 - sparse_categorical_accuracy: 0.9091
# Epoch 88/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.2078 - sparse_categorical_accuracy: 0.9318
# Epoch 89/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.1868 - sparse_categorical_accuracy: 0.9432
# Epoch 90/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.2213 - sparse_categorical_accuracy: 0.9432
# Epoch 91/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9659
# Epoch 92/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1814 - sparse_categorical_accuracy: 0.9432
# Epoch 93/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.1828 - sparse_categorical_accuracy: 0.9318
# Epoch 94/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1488 - sparse_categorical_accuracy: 0.9318
# Epoch 95/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9432
# Epoch 96/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1317 - sparse_categorical_accuracy: 0.9659
# Epoch 97/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9659
# Epoch 98/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9659
# Epoch 99/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9659
# Epoch 100/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0802 - sparse_categorical_accuracy: 0.9886
# 276/276 - 210s - 210s/epoch - 761ms/step
# 0 epochs result:
#               precision    recall  f1-score   support
#
#            0       0.65      0.40      0.50      1697
#            1       0.57      0.69      0.63      4599
#            2       0.37      0.33      0.35      2531
#
#     accuracy                           0.53      8827
#    macro avg       0.53      0.47      0.49      8827
# weighted avg       0.53      0.53      0.52      8827
#
# Epoch 1/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9545
# Epoch 2/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0755 - sparse_categorical_accuracy: 0.9659
# Epoch 3/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.1111 - sparse_categorical_accuracy: 0.9659
# Epoch 4/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9659
# Epoch 5/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0405 - sparse_categorical_accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0444 - sparse_categorical_accuracy: 0.9886
# Epoch 7/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9773
# Epoch 8/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9659
# Epoch 9/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9886
# Epoch 10/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9773
# Epoch 11/100
# 3/3 [==============================] - 11s 3s/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9659
# Epoch 12/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9886
# Epoch 13/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9773
# Epoch 14/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0669 - sparse_categorical_accuracy: 0.9773
# Epoch 15/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9773
# Epoch 16/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0411 - sparse_categorical_accuracy: 0.9886
# Epoch 17/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9886
# Epoch 18/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0185 - sparse_categorical_accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0151 - sparse_categorical_accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0287 - sparse_categorical_accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0204 - sparse_categorical_accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0190 - sparse_categorical_accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9318
# Epoch 25/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4145 - sparse_categorical_accuracy: 0.9205
# Epoch 26/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2372 - sparse_categorical_accuracy: 0.9318
# Epoch 27/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9773
# Epoch 28/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9886
# Epoch 29/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9545
# Epoch 30/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9886
# Epoch 31/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9886
# Epoch 32/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9886
# Epoch 33/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9659
# Epoch 34/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0616 - sparse_categorical_accuracy: 0.9773
# Epoch 35/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9659
# Epoch 36/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9886
# Epoch 37/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0362 - sparse_categorical_accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9773
# Epoch 39/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9886
# Epoch 40/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9773
# Epoch 41/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9773
# Epoch 42/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9773
# Epoch 43/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0183 - sparse_categorical_accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9773
# Epoch 45/100
# 3/3 [==============================] - 11s 3s/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9886
# Epoch 46/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0184 - sparse_categorical_accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9659
# Epoch 48/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9886
# Epoch 49/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0059 - sparse_categorical_accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0263 - sparse_categorical_accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0196 - sparse_categorical_accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9886
# Epoch 53/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9886
# Epoch 54/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9886
# Epoch 55/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0085 - sparse_categorical_accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0106 - sparse_categorical_accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0161 - sparse_categorical_accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9886
# Epoch 59/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9886
# Epoch 60/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9886
# Epoch 61/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9886
# Epoch 62/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0049 - sparse_categorical_accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9886
# Epoch 64/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0079 - sparse_categorical_accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0089 - sparse_categorical_accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0049 - sparse_categorical_accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0068 - sparse_categorical_accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9886
# Epoch 72/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0040 - sparse_categorical_accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0111 - sparse_categorical_accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 11s 3s/step - loss: 0.0087 - sparse_categorical_accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0040 - sparse_categorical_accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9886
# Epoch 80/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9886
# Epoch 81/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9886
# Epoch 83/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9886
# Epoch 85/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9886
# Epoch 86/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0052 - sparse_categorical_accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9773
# Epoch 88/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2596 - sparse_categorical_accuracy: 0.9318
# Epoch 89/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1795 - sparse_categorical_accuracy: 0.9432
# Epoch 90/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9886
# Epoch 91/100
# 3/3 [==============================] - 9s 2s/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9886
# Epoch 92/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0101 - sparse_categorical_accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9886
# Epoch 94/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0119 - sparse_categorical_accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9886
# Epoch 96/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9773
# Epoch 97/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0148 - sparse_categorical_accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0083 - sparse_categorical_accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0147 - sparse_categorical_accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000
# 276/276 - 219s - 219s/epoch - 794ms/step
# 100 epochs result:
#               precision    recall  f1-score   support
#
#            0       0.64      0.39      0.49      1697
#            1       0.57      0.71      0.63      4599
#            2       0.37      0.29      0.33      2531
#
#     accuracy                           0.53      8827
#    macro avg       0.53      0.47      0.48      8827
# weighted avg       0.53      0.53      0.52      8827
#
# Epoch 1/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0075 - sparse_categorical_accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0036 - sparse_categorical_accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0116 - sparse_categorical_accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 11s 3s/step - loss: 0.0184 - sparse_categorical_accuracy: 1.0000
# Epoch 5/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d5857a04af15> in <cell line: 1>()
# ----> 1 model = Training_Step()
#
# <ipython-input-7-534c7380dfa8> in Training_Step()
#      15   DoiNhan(y_test)
#      16
# ---> 17   CNN_model = train_CNN(X_train, y_train, X_test, y_test)
#      18   return CNN_model
#
# <ipython-input-6-cd1a6c2ac3cc> in train_CNN(X, y, X_test, y_test)
#      38     metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
#      39     for i in range(5):
# ---> 40       model.fit(X, y, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, shuffle=True)
#      41       predictions = model.predict(X_test, verbose=2, batch_size=BATCH_SIZE)
#      42       y_pred = np.argmax(predictions, axis=-1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
